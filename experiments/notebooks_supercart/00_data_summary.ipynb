# %%
# %load_ext autoreload
# %autoreload 2
import os
import pickle as pkl
from typing import Dict, Any

import numpy as np
import pandas as pd
from sklearn.datasets import fetch_openml
import matplotlib as mpl
import matplotlib.pyplot as plt
from copy import deepcopy
mpl.rcParams['figure.dpi'] = 250

# change working directory to project root
if os.getcwd().split('/')[-1] == 'notebooks':
    os.chdir('../..')
from experiments.notebooks import viz
from experiments.data_util import get_clean_dataset
from experiments.config.datasets import DATASETS_CLASSIFICATION
pd.options.display.max_rows = 100
# Out:
# /Volumes/GoogleDrive/My Drive/research/rules/imodels/experiments/notebooks

# %% [markdown]
# # classification dataset stats

# %%
metadata = []
columns = ['Name', 'Samples', 'Features', 'Class 0', 'Class 1', 'Majority class %']
for dset_name, dset_file in DATASETS_CLASSIFICATION:
    X, y, feat_names = get_clean_dataset(dset_file)
#     X = np.nan_to_num(X, 0)
    shape = X.shape
    class_counts = np.unique(y, return_counts=True)[1]
    metadata.append([dset_name.capitalize(), shape[0], shape[1], class_counts[0], class_counts[1],
                     np.round(100 * np.max(class_counts) / np.sum(class_counts), decimals=1)])

metadata = pd.DataFrame(metadata, columns=columns) #.set_index('Name')
metadata
# Out:
#             Name  Samples  Features  Class 0  Class 1  Majority class %
# 0     Recidivism     6172        20     3182     2990              51.6
# 1         Credit    30000        33    23364     6636              77.9
# 2       Juvenile     3640       286     3153      487              86.6
# 3    Readmission   101763       150    54861    46902              53.9
# 4  Breast-cancer      277        17      196       81              70.8
# 5       Credit-g     1000        60      300      700              70.0
# 6       Haberman      306         3       81      225              73.5
# 7          Heart      270        15      150      120              55.6

# %%
print(metadata.to_latex(index=False))
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
#          Name &  Samples &  Features &  Class 0 &  Class 1 &  Majority class \% \\
# \midrule
#    Recidivism &     6172 &        20 &     3182 &     2990 &              51.6 \\
#        Credit &    30000 &        33 &    23364 &     6636 &              77.9 \\
#      Juvenile &     3640 &       286 &     3153 &      487 &              86.6 \\
#   Readmission &   101763 &       150 &    54861 &    46902 &              53.9 \\
# Breast-cancer &      277 &        17 &      196 &       81 &              70.8 \\
#      Credit-g &     1000 &        60 &      300 &      700 &              70.0 \\
#      Haberman &      306 &         3 &       81 &      225 &              73.5 \\
#         Heart &      270 &        15 &      150 &      120 &              55.6 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # regression dataset names

# %%
from pmlb import fetch_data, classification_dataset_names

# %%
pmlb_meta = pd.read_csv('../data/pmlb_data/pmlb_metadata.csv').sort_values(by=['n_observations', 'n_features'], ascending=False)

# %%
pmlb_meta[(pmlb_meta.Task == 'regression') & ~(pmlb_meta.Dataset.str.contains('feynman'))].head(100)
# Out:
#                               Dataset  n_observations  n_features  n_classes  \
# 174                        1595_poker         1025010          10        NaN
# 168                      1191_BNG_pbc         1000000          18        NaN
# 170                  1196_BNG_pharynx         1000000          10        NaN
# 173                 1203_BNG_pwLinear          177147          10        NaN
# 172              1201_BNG_breastTumor          116640           9        NaN
# 181                      215_2dplanes           40768          10        NaN
# 189                            344_mv           40768          10        NaN
# 207                         564_fried           40768          10        NaN
# 169                   1193_BNG_lowbwt           31104           9        NaN
# 209                     574_house_16H           22784          16        NaN
# 182                      218_house_8L           22784           8        NaN
# 199                        537_houses           20640           8        NaN
# 171               1199_BNG_echoMonths           17496           9        NaN
# 178                           201_pol           15000          48        NaN
# 177                       197_cpu_act            8192          21        NaN
# 208                       573_cpu_act            8192          21        NaN
# 184                     227_cpu_small            8192          12        NaN
# 206                     562_cpu_small            8192          12        NaN
# 183                       225_puma8NH            8192           8        NaN
# 192                          503_wind            6574          14        NaN
# 188               294_satellite_image            6435          36        NaN
# 282                            banana            5300           2        NaN
# 198                        529_pollen            3848           4        NaN
# 416                           titanic            2201           3        NaN
# 190  4544_GeographicalOriginalofMusic            1059         117        NaN
# 216               588_fri_c4_1000_100            1000         100        NaN
# 213                583_fri_c1_1000_50            1000          50        NaN
# 218                590_fri_c0_1000_50            1000          50        NaN
# 234                607_fri_c4_1000_50            1000          50        NaN
# 243                618_fri_c3_1000_50            1000          50        NaN
# 246                622_fri_c2_1000_50            1000          50        NaN
# 215                586_fri_c3_1000_25            1000          25        NaN
# 217                589_fri_c2_1000_25            1000          25        NaN
# 220                592_fri_c4_1000_25            1000          25        NaN
# 226                598_fri_c0_1000_25            1000          25        NaN
# 244                620_fri_c1_1000_25            1000          25        NaN
# 163                          1028_SWD            1000          10        NaN
# 221                593_fri_c1_1000_10            1000          10        NaN
# 223                595_fri_c0_1000_10            1000          10        NaN
# 233                606_fri_c2_1000_10            1000          10        NaN
# 235                608_fri_c3_1000_10            1000          10        NaN
# 247                623_fri_c4_1000_10            1000          10        NaN
# 227                 599_fri_c2_1000_5            1000           5        NaN
# 236                 609_fri_c0_1000_5            1000           5        NaN
# 238                 612_fri_c1_1000_5            1000           5        NaN
# 251                 628_fri_c3_1000_5            1000           5        NaN
# 164                          1029_LEV            1000           4        NaN
# 165                          1030_ERA            1000           4        NaN
# 275                 666_rmftsa_ladata             508          10        NaN
# 241                 616_fri_c4_500_50             500          50        NaN
# 249                 626_fri_c2_500_50             500          50        NaN
# 256                 637_fri_c1_500_50             500          50        NaN
# 260                 645_fri_c3_500_50             500          50        NaN
# 265                 650_fri_c0_500_50             500          50        NaN
# 211                 581_fri_c3_500_25             500          25        NaN
# 212                 582_fri_c1_500_25             500          25        NaN
# 214                 584_fri_c4_500_25             500          25        NaN
# 253                 633_fri_c0_500_25             500          25        NaN
# 258                 643_fri_c2_500_25             500          25        NaN
# 231                 604_fri_c4_500_10             500          10        NaN
# 250                 627_fri_c2_500_10             500          10        NaN
# 257                 641_fri_c1_500_10             500          10        NaN
# 261                 646_fri_c3_500_10             500          10        NaN
# 268                 654_fri_c0_500_10             500          10        NaN
# 195                          522_pm10             500           7        NaN
# 201                           547_no2             500           7        NaN
# 225                  597_fri_c2_500_5             500           5        NaN
# 242                  617_fri_c3_500_5             500           5        NaN
# 252                  631_fri_c1_500_5             500           5        NaN
# 264                  649_fri_c0_500_5             500           5        NaN
# 162                          1027_ESL             488           4        NaN
# 202            556_analcatdata_apnea2             475           3        NaN
# 203            557_analcatdata_apnea1             475           3        NaN
# 402                  strogatz_bacres1             400           2        NaN
# 403                  strogatz_bacres2             400           2        NaN
# 404                  strogatz_barmag1             400           2        NaN
# 405                  strogatz_barmag2             400           2        NaN
# 406                  strogatz_glider1             400           2        NaN
# 407                  strogatz_glider2             400           2        NaN
# 408                      strogatz_lv1             400           2        NaN
# 409                      strogatz_lv2             400           2        NaN
# 410                strogatz_predprey1             400           2        NaN
# 411                strogatz_predprey2             400           2        NaN
# 412               strogatz_shearflow1             400           2        NaN
# 413               strogatz_shearflow2             400           2        NaN
# 414                     strogatz_vdp1             400           2        NaN
# 415                     strogatz_vdp2             400           2        NaN
# 194                        519_vinnie             380           2        NaN
# 278            690_visualizing_galaxy             323           4        NaN
# 204                       560_bodyfat             252          14        NaN
# 230                 603_fri_c0_250_50             250          50        NaN
# 263                 648_fri_c1_250_50             250          50        NaN
# 232                 605_fri_c2_250_25             250          25        NaN
# 259                 644_fri_c4_250_25             250          25        NaN
# 267                 653_fri_c0_250_25             250          25        NaN
# 271                 658_fri_c3_250_25             250          25        NaN
# 229                 602_fri_c3_250_10             250          10        NaN
# 240                 615_fri_c4_250_10             250          10        NaN
# 255                 635_fri_c0_250_10             250          10        NaN
# 262                 647_fri_c1_250_10             250          10        NaN
#
#        Endpoint  Imbalance        Task  Metadata
# 174  continuous       0.37  regression       NaN
# 168  continuous       0.00  regression       NaN
# 170  continuous       0.00  regression       NaN
# 173  continuous       0.00  regression       NaN
# 172  continuous       0.04  regression       NaN
# 181  continuous       0.00  regression       NaN
# 189  continuous       0.00  regression       NaN
# 207  continuous       0.00  regression       NaN
# 169  continuous       0.00  regression       NaN
# 209  continuous       0.02  regression       NaN
# 182  continuous       0.02  regression       NaN
# 199  continuous       0.00  regression       NaN
# 171  continuous       0.00  regression       NaN
# 178  continuous       0.37  regression       NaN
# 177  continuous       0.02  regression       NaN
# 208  continuous       0.02  regression       NaN
# 184  continuous       0.02  regression       NaN
# 206  continuous       0.02  regression       NaN
# 183  continuous       0.00  regression       NaN
# 192  continuous       0.00  regression       NaN
# 188  continuous       0.03  regression       NaN
# 282  continuous       0.01  regression       NaN
# 198  continuous       0.00  regression       NaN
# 416  continuous       0.13  regression       NaN
# 190  continuous       0.00  regression       NaN
# 216  continuous       0.00  regression       NaN
# 213  continuous       0.00  regression       NaN
# 218  continuous       0.00  regression       NaN
# 234  continuous       0.00  regression       NaN
# 243  continuous       0.00  regression       NaN
# 246  continuous       0.00  regression       NaN
# 215  continuous       0.00  regression       NaN
# 217  continuous       0.00  regression       NaN
# 220  continuous       0.00  regression       NaN
# 226  continuous       0.00  regression       NaN
# 244  continuous       0.00  regression       NaN
# 163  continuous       0.11  regression       NaN
# 221  continuous       0.00  regression       NaN
# 223  continuous       0.00  regression       NaN
# 233  continuous       0.00  regression       NaN
# 235  continuous       0.00  regression       NaN
# 247  continuous       0.00  regression       NaN
# 227  continuous       0.00  regression       NaN
# 236  continuous       0.00  regression       NaN
# 238  continuous       0.00  regression       NaN
# 251  continuous       0.00  regression       NaN
# 164  continuous       0.11  regression       NaN
# 165  continuous       0.03  regression       NaN
# 275  continuous       0.00  regression       NaN
# 241  continuous       0.00  regression       NaN
# 249  continuous       0.00  regression       NaN
# 256  continuous       0.00  regression       NaN
# 260  continuous       0.00  regression       NaN
# 265  continuous       0.00  regression       NaN
# 211  continuous       0.00  regression       NaN
# 212  continuous       0.00  regression       NaN
# 214  continuous       0.00  regression       NaN
# 253  continuous       0.00  regression       NaN
# 258  continuous       0.00  regression       NaN
# 231  continuous       0.00  regression       NaN
# 250  continuous       0.00  regression       NaN
# 257  continuous       0.00  regression       NaN
# 261  continuous       0.00  regression       NaN
# 268  continuous       0.00  regression       NaN
# 195  continuous       0.01  regression       NaN
# 201  continuous       0.00  regression       NaN
# 225  continuous       0.00  regression       NaN
# 242  continuous       0.00  regression       NaN
# 252  continuous       0.00  regression       NaN
# 264  continuous       0.00  regression       NaN
# 162  continuous       0.10  regression       NaN
# 202  continuous       0.27  regression       NaN
# 203  continuous       0.33  regression       NaN
# 402  continuous       0.00  regression       NaN
# 403  continuous       0.00  regression       NaN
# 404  continuous       0.00  regression       NaN
# 405  continuous       0.00  regression       NaN
# 406  continuous       0.00  regression       NaN
# 407  continuous       0.00  regression       NaN
# 408  continuous       0.00  regression       NaN
# 409  continuous       0.00  regression       NaN
# 410  continuous       0.00  regression       NaN
# 411  continuous       0.00  regression       NaN
# 412  continuous       0.00  regression       NaN
# 413  continuous       0.00  regression       NaN
# 414  continuous       0.00  regression       NaN
# 415  continuous       0.00  regression       NaN
# 194  continuous       0.03  regression       NaN
# 278  continuous       0.00  regression       NaN
# 204  continuous       0.00  regression       NaN
# 230  continuous       0.00  regression       NaN
# 263  continuous       0.00  regression       NaN
# 232  continuous       0.00  regression       NaN
# 259  continuous       0.00  regression       NaN
# 267  continuous       0.00  regression       NaN
# 271  continuous       0.00  regression       NaN
# 229  continuous       0.00  regression       NaN
# 240  continuous       0.00  regression       NaN
# 255  continuous       0.00  regression       NaN
# 262  continuous       0.00  regression       NaN

# %%
X, y, feature_names = get_clean_dataset('542_pollution', data_source='pmlb')

# %%
feature_names
# Out:
# Index(['PREC', 'JANT', 'JULT', 'OVR65', 'POPN', 'EDUC', 'HOUS', 'DENS', 'NONW',
#        'WWDRK', 'POOR', 'HC', 'NOX', 'SO2', 'HUMID', 'target'],
#       dtype='object')

# %%
y
# Out:
# array([ 921.86999512,  997.875     ,  962.35400391,  982.29101562,
#        1071.28894043, 1030.38000488,  934.70001221,  899.5289917 ,
#        1001.90197754,  912.34698486, 1017.61297607, 1024.88500977,
#         970.46697998,  985.95001221,  958.83898926,  860.10101318,
#         936.23400879,  871.76599121,  959.2210083 ,  941.18103027,
#         891.70800781,  871.3380127 ,  971.12200928,  887.46600342,
#         952.5289917 ,  968.66497803,  919.72900391,  844.05297852,
#         861.83300781,  989.26501465, 1006.48999023,  861.43902588,
#         929.15002441,  857.62200928,  961.00897217,  923.23400879,
#        1113.15600586,  994.64801025, 1015.02301025,  991.28997803,
#         893.99102783,  938.5       ,  946.18499756, 1025.50195312,
#         874.28100586,  953.55999756,  839.70898438,  911.70098877,
#         790.73297119,  899.26397705,  904.1550293 ,  950.67199707,
#         972.46398926,  912.20202637,  967.80297852,  823.76397705,
#        1003.50201416,  895.69598389,  911.8170166 ,  954.4420166 ])
