# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas as pd
from autogluon.tabular import TabularDataset, TabularPredictor

# %% [markdown]
# **load data**

# %%
# train data
train_data = TabularDataset('https://autogluon.s3.amazonaws.com/datasets/Inc/train.csv')
subsample_size = 100  # subsample subset of data for faster demo, try setting this to much larger values
train_data = train_data.sample(n=subsample_size, random_state=0)
# train_data.head()

# test data
test_data = TabularDataset('https://autogluon.s3.amazonaws.com/datasets/Inc/test.csv')
label = 'class'
y_test = test_data[label]  # values to predict
test_data_nolab = test_data.drop(columns=[label])  # delete label column to prove we're not cheating
# test_data_nolab.head()
# print("Summary of class variable: \n", train_data[label].describe())

# %% [markdown]
# # Fit models using interpretable preset

# %% [markdown]
# **fit using interpretable preset**

# %%
predictor = TabularPredictor(label=label).fit(train_data, presets='interpretable', time_limit=8, verbosity=2)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20211206_020056/"
# Presets specified: ['interpretable']
# Beginning AutoGluon training ... Time limit = 8s
# AutoGluon will save models to "AutogluonModels/ag-20211206_020056/"
# AutoGluon Version:  0.3.2b20211202
# Python Version:     3.7.0
# Operating System:   Darwin
# Train Data Rows:    100
# Train Data Columns: 14
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [' >50K', ' <=50K']
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 =  >50K, class 0 =  <=50K
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive ( >50K) vs negative ( <=50K) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    7175.15 MB
# 	Train Data (Original)  Memory Usage: 0.06 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('int', [])    : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]
# 		('object', []) : 8 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 7 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 		('int', [])       : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]
# 		('int', ['bool']) : 1 | ['sex']
# 	0.1s = Fit runtime
# 	14 features in original data used to generate 14 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.01 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.17s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric argument of fit()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 80, Val Rows: 20
# Fitting 11 L1 models ...
# Fitting model: RuleFit ... Training model for up to 7.83s of the 7.83s of remaining time.
# 	0.75	 = Validation score   (accuracy)
# 	1.36s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RuleFit_2 ... Training model for up to 6.43s of the 6.43s of remaining time.
# 	0.75	 = Validation score   (accuracy)
# 	0.49s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: RuleFit_3 ... Training model for up to 5.92s of the 5.92s of remaining time.
# 	0.75	 = Validation score   (accuracy)
# 	0.54s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: GreedyTree ... Training model for up to 5.36s of the 5.36s of remaining time.
# 	0.85	 = Validation score   (accuracy)
# 	0.02s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: OptimalRuleList ... Training model for up to 5.33s of the 5.33s of remaining time.
# 	0.75	 = Validation score   (accuracy)
# 	0.07s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: OptimalRuleList_2 ... Training model for up to 5.25s of the 5.25s of remaining time.
# 	0.75	 = Validation score   (accuracy)
# 	0.09s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: OptimalRuleList_3 ... Training model for up to 5.15s of the 5.15s of remaining time.
# 	0.75	 = Validation score   (accuracy)
# 	0.02s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: OptimalRuleList_4 ... Training model for up to 5.12s of the 5.11s of remaining time.
# 	0.75	 = Validation score   (accuracy)
# 	0.02s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: OptimalTree ... Training model for up to 5.08s of the 5.08s of remaining time.
# /Users/chandan/rules/imodels/imodels/tree/gosdt/pygosdt.py:127: UserWarning: Should install gosdt extension. On x86_64 linux or macOS: 'pip install gosdt'. On other platforms, see https://github.com/keyan3/GeneralizedOptimalSparseDecisionTrees. Defaulting to Non-optimal DecisionTreeClassifier.
#   "Should install gosdt extension. On x86_64 linux or macOS: "
# 	0.85	 = Validation score   (accuracy)
# 	0.03s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: BoostedRules ... Training model for up to 5.03s of the 5.03s of remaining time.
# 	0.75	 = Validation score   (accuracy)
# 	0.03s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: BoostedRules_2 ... Training model for up to 4.99s of the 4.99s of remaining time.
# 	0.75	 = Validation score   (accuracy)
# 	0.04s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 7.83s of the 4.8s of remaining time.
# 	0.85	 = Validation score   (accuracy)
# 	0.24s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 3.48s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20211206_020056/")

# %%
predictor.leaderboard(silent=True)
# Out:
#                   model  score_val  pred_time_val  fit_time  \
# 0            GreedyTree       0.85       0.009729  0.021507
# 1   WeightedEnsemble_L2       0.85       0.010475  0.264943
# 2           OptimalTree       0.85       0.011716  0.026156
# 3       OptimalRuleList       0.75       0.006860  0.069624
# 4     OptimalRuleList_2       0.75       0.007151  0.086562
# 5             RuleFit_3       0.75       0.008418  0.544459
# 6     OptimalRuleList_3       0.75       0.008560  0.022690
# 7     OptimalRuleList_4       0.75       0.009097  0.024621
# 8          BoostedRules       0.75       0.010914  0.031247
# 9        BoostedRules_2       0.75       0.013277  0.035402
# 10            RuleFit_2       0.75       0.021511  0.486804
# 11              RuleFit       0.75       0.025171  1.364287
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.009729           0.021507            1       True
# 1                 0.000746           0.243436            2       True
# 2                 0.011716           0.026156            1       True
# 3                 0.006860           0.069624            1       True
# 4                 0.007151           0.086562            1       True
# 5                 0.008418           0.544459            1       True
# 6                 0.008560           0.022690            1       True
# 7                 0.009097           0.024621            1       True
# 8                 0.010914           0.031247            1       True
# 9                 0.013277           0.035402            1       True
# 10                0.021511           0.486804            1       True
# 11                0.025171           1.364287            1       True
#
#     fit_order
# 0           4
# 1          12
# 2           9
# 3           5
# 4           6
# 5           3
# 6           7
# 7           8
# 8          10
# 9          11
# 10          2
# 11          1

# %%
predictor.interpretable_models_summary()
# Out:
#                             model_types  model_performance  complexity  \
# GreedyTree              GreedyTreeModel               0.85         5.0
# OptimalTree            OptimalTreeModel               0.85         5.0
# RuleFit_3                  RuleFitModel               0.75         0.0
# OptimalRuleList_3  OptimalRuleListModel               0.75         1.0
# OptimalRuleList_4  OptimalRuleListModel               0.75         1.0
# OptimalRuleList    OptimalRuleListModel               0.75         3.0
# OptimalRuleList_2  OptimalRuleListModel               0.75         3.0
# BoostedRules          BoostedRulesModel               0.75        10.0
# RuleFit                    RuleFitModel               0.75        16.0
# RuleFit_2                  RuleFitModel               0.75        16.0
# BoostedRules_2        BoostedRulesModel               0.75        20.0
#
#                             model_best  \
# GreedyTree         WeightedEnsemble_L2
# OptimalTree        WeightedEnsemble_L2
# RuleFit_3          WeightedEnsemble_L2
# OptimalRuleList_3  WeightedEnsemble_L2
# OptimalRuleList_4  WeightedEnsemble_L2
# OptimalRuleList    WeightedEnsemble_L2
# OptimalRuleList_2  WeightedEnsemble_L2
# BoostedRules       WeightedEnsemble_L2
# RuleFit            WeightedEnsemble_L2
# RuleFit_2          WeightedEnsemble_L2
# BoostedRules_2     WeightedEnsemble_L2
#
#                                                          model_paths  \
# GreedyTree         AutogluonModels/ag-20211206_020056/models/Gree...
# OptimalTree        AutogluonModels/ag-20211206_020056/models/Opti...
# RuleFit_3          AutogluonModels/ag-20211206_020056/models/Rule...
# OptimalRuleList_3  AutogluonModels/ag-20211206_020056/models/Opti...
# OptimalRuleList_4  AutogluonModels/ag-20211206_020056/models/Opti...
# OptimalRuleList    AutogluonModels/ag-20211206_020056/models/Opti...
# OptimalRuleList_2  AutogluonModels/ag-20211206_020056/models/Opti...
# BoostedRules       AutogluonModels/ag-20211206_020056/models/Boos...
# RuleFit            AutogluonModels/ag-20211206_020056/models/Rule...
# RuleFit_2          AutogluonModels/ag-20211206_020056/models/Rule...
# BoostedRules_2     AutogluonModels/ag-20211206_020056/models/Boos...
#
#                    model_fit_times  model_pred_times  num_bag_folds  \
# GreedyTree                0.021507          0.009729              0
# OptimalTree               0.026156          0.011716              0
# RuleFit_3                 0.544459          0.008418              0
# OptimalRuleList_3         0.022690          0.008560              0
# OptimalRuleList_4         0.024621          0.009097              0
# OptimalRuleList           0.069624          0.006860              0
# OptimalRuleList_2         0.086562          0.007151              0
# BoostedRules              0.031247          0.010914              0
# RuleFit                   1.364287          0.025171              0
# RuleFit_2                 0.486804          0.021511              0
# BoostedRules_2            0.035402          0.013277              0
#
#                    max_stack_level  num_classes  \
# GreedyTree                       2            2
# OptimalTree                      2            2
# RuleFit_3                        2            2
# OptimalRuleList_3                2            2
# OptimalRuleList_4                2            2
# OptimalRuleList                  2            2
# OptimalRuleList_2                2            2
# BoostedRules                     2            2
# RuleFit                          2            2
# RuleFit_2                        2            2
# BoostedRules_2                   2            2
#
#                                          model_hyperparams
# GreedyTree                             {'random_state': 0}
# OptimalTree                            {'random_state': 0}
# RuleFit_3             {'random_state': 0, 'max_rules': 30}
# OptimalRuleList_3            {'random_state': 0, 'c': 0.1}
# OptimalRuleList_4            {'random_state': 0, 'c': 1.0}
# OptimalRuleList            {'random_state': 0, 'c': 0.001}
# OptimalRuleList_2           {'random_state': 0, 'c': 0.01}
# BoostedRules        {'random_state': 0, 'n_estimators': 5}
# RuleFit                {'random_state': 0, 'max_rules': 7}
# RuleFit_2             {'random_state': 0, 'max_rules': 15}
# BoostedRules_2     {'random_state': 0, 'n_estimators': 10}

# %%
predictor.print_interpretable_rules() # automatically selects a model (here, RuleList)
# Out:
# GreedyTree:
# |--- relationship_0 <= 0.50
# |   |--- relationship_5 <= 0.50
# |   |   |--- relationship_2 <= 0.50
# |   |   |   |--- weights: [40.00, 0.00] class: 0
# |   |   |--- relationship_2 >  0.50
# |   |   |   |--- race_2 <= 0.50
# |   |   |   |   |--- weights: [0.00, 1.00] class: 1
# |   |   |   |--- race_2 >  0.50
# |   |   |   |   |--- weights: [1.00, 0.00] class: 0
# |   |--- relationship_5 >  0.50
# |   |   |--- weights: [4.00, 4.00] class: 0
# |--- relationship_0 >  0.50
# |   |--- race_2 <= 0.50
# |   |   |--- weights: [1.00, 0.00] class: 0
# |   |--- race_2 >  0.50
# |   |   |--- weights: [13.00, 16.00] class: 1

# %%
for model_name in ['OptimalRuleList', 'BoostedRules', 'RuleFit', 'GreedyTree', 'OptimalTree']:
    predictor.print_interpretable_rules(model_name=model_name)
# Out:
# OptimalRuleList:
#
#    0.0 / 80 (positive class / total)
# 	↓
# If race_0                              → 0.0 /    4 (0.0%)
# 	↓
#    0.0 /    76
# 	↓
# If race_0  & relationship_2 == 0       → 0.0 /    0 (0.0%)
# 	↓
#    0.0 /    76
# 	↓
# If relationship_0 == 0                 → 0.0 /   47 (0.0%)
# 	↓
#    0.0 /    29
# 	↓
# If relationship_0 == 0 & race_0 == 0   → 0.0 /    0 (0.0%)
# 	↓
#    0.0 /    29
#
# BoostedRules:
# Rule → predicted probability (final prediction is weighted sum of all predictions)
#   If relationship_0 <= 0.5 → 0.38 (weight: 0.58)
#   If relationship_0 > 0.5 → 0.10 (weight: 0.72)
#   If relationship_5 <= 0.5 → 0.74 (weight: 0.17)
#   If relationship_5 > 0.5 → 0.03 (weight: 0.30)
#   If relationship_1 <= 0.5 → 0.38 (weight: 0.34)
#
# RuleFit:
#                                                                       rule  coef
#                            relationship_0 <= 0.5 and relationship_2 <= 0.5 -0.00
#                            relationship_0 <= 0.5 and relationship_2 <= 0.5 -0.00
#  relationship_0 <= 0.5 and relationship_2 <= 0.5 and relationship_5 <= 0.5 -0.47
#  relationship_0 <= 0.5 and relationship_2 <= 0.5 and relationship_5 <= 0.5 -0.56
#  relationship_0 <= 0.5 and relationship_2 <= 0.5 and relationship_5 <= 0.5 -0.73
#          relationship_0 <= 0.5 and relationship_5 <= 0.5 and race_0 <= 0.5 -0.89
#
# GreedyTree:
# |--- relationship_0 <= 0.50
# |   |--- relationship_5 <= 0.50
# |   |   |--- relationship_2 <= 0.50
# |   |   |   |--- weights: [40.00, 0.00] class: 0
# |   |   |--- relationship_2 >  0.50
# |   |   |   |--- race_2 <= 0.50
# |   |   |   |   |--- weights: [0.00, 1.00] class: 1
# |   |   |   |--- race_2 >  0.50
# |   |   |   |   |--- weights: [1.00, 0.00] class: 0
# |   |--- relationship_5 >  0.50
# |   |   |--- weights: [4.00, 4.00] class: 0
# |--- relationship_0 >  0.50
# |   |--- race_2 <= 0.50
# |   |   |--- weights: [1.00, 0.00] class: 0
# |   |--- race_2 >  0.50
# |   |   |--- weights: [13.00, 16.00] class: 1
#
# GreedyTree:
# |--- relationship_0 <= 0.50
# |   |--- relationship_5 <= 0.50
# |   |   |--- relationship_2 <= 0.50
# |   |   |   |--- weights: [40.00, 0.00] class: 0
# |   |   |--- relationship_2 >  0.50
# |   |   |   |--- race_2 <= 0.50
# |   |   |   |   |--- weights: [0.00, 1.00] class: 1
# |   |   |   |--- race_2 >  0.50
# |   |   |   |   |--- weights: [1.00, 0.00] class: 0
# |   |--- relationship_5 >  0.50
# |   |   |--- weights: [4.00, 4.00] class: 0
# |--- relationship_0 >  0.50
# |   |--- race_2 <= 0.50
# |   |   |--- weights: [1.00, 0.00] class: 0
# |   |--- race_2 >  0.50
# |   |   |--- weights: [13.00, 16.00] class: 1

# %% [markdown]
# **fit custom model once (could also include other default models here)**

# %%
from autogluon.tabular.models import RuleFitModel, GreedyTreeModel, OptimalRuleListModel, \
  BayesianRuleSetModel, OptimalTreeModel, BoostedRulesModel

# hyperparams = get_hyperparameter_config('default') # get all default hyperparams for various models
custom_hyperparameters = {
#     RuleFitModel: [{}, {'max_rules': 4}], # empty brackets are dfeault hyperparams
#     GreedyTreeModel: [{}],
    OptimalTreeModel: [{}],
#     BoostedRulesModel: [{}],
#     OptimalRuleListModel: [{}]
}  # Train 3 CustomRandomForestModel with different hyperparameters
predictor = TabularPredictor(label=label).fit(train_data, hyperparameters=custom_hyperparameters, verbosity=2)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20211206_020137/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20211206_020137/"
# AutoGluon Version:  0.3.2b20211202
# Python Version:     3.7.0
# Operating System:   Darwin
# Train Data Rows:    100
# Train Data Columns: 14
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [' >50K', ' <=50K']
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 =  >50K, class 0 =  <=50K
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive ( >50K) vs negative ( <=50K) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    7229.58 MB
# 	Train Data (Original)  Memory Usage: 0.06 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('int', [])    : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]
# 		('object', []) : 8 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 7 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 		('int', [])       : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]
# 		('int', ['bool']) : 1 | ['sex']
# 	0.1s = Fit runtime
# 	14 features in original data used to generate 14 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.01 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.16s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric argument of fit()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 80, Val Rows: 20
# Custom Model Type Detected: <class 'autogluon.tabular.models.imodels.imodels_models.OptimalTreeModel'>
# Fitting 1 L1 models ...
# Fitting model: OptimalTree ...
# /Users/chandan/rules/imodels/imodels/tree/gosdt/pygosdt.py:127: UserWarning: Should install gosdt extension. On x86_64 linux or macOS: 'pip install gosdt'. On other platforms, see https://github.com/keyan3/GeneralizedOptimalSparseDecisionTrees. Defaulting to Non-optimal DecisionTreeClassifier.
#   "Should install gosdt extension. On x86_64 linux or macOS: "
# 	0.85	 = Validation score   (accuracy)
# 	0.03s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	0.85	 = Validation score   (accuracy)
# 	0.0s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 0.28s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20211206_020137/")

# %% [markdown]
# # tune custom models

# %%
from autogluon.core.space import Categorical, Int, Real
from autogluon.tabular.configs.hyperparameter_configs import get_hyperparameter_config

custom_hyperparameters_hpo = {
    RuleFitModel: {
        'tree_size': Int(lower=5, upper=30),
        'max_rules': Int(lower=2, upper=15),
    },
    GreedyTreeModel: {
        'max_leaf_nodes': Int(lower=2, upper=30),
        'ccp_alpha': Real(lower=0, upper=5),
    }
}
# Hyperparameter tune CustomRandomForestModel for 20 seconds
predictor = TabularPredictor(label=label).fit(train_data,
                                              hyperparameters=custom_hyperparameters_hpo,
                                              hyperparameter_tune_kwargs='auto',  # enables HPO
                                              time_limit=60)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20211206_020147/"
# Warning: hyperparameter tuning is currently experimental and may cause the process to hang.
# Beginning AutoGluon training ... Time limit = 60s
# AutoGluon will save models to "AutogluonModels/ag-20211206_020147/"
# AutoGluon Version:  0.3.2b20211202
# Python Version:     3.7.0
# Operating System:   Darwin
# Train Data Rows:    100
# Train Data Columns: 14
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [' >50K', ' <=50K']
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 =  >50K, class 0 =  <=50K
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive ( >50K) vs negative ( <=50K) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    7242.29 MB
# 	Train Data (Original)  Memory Usage: 0.06 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('int', [])    : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]
# 		('object', []) : 8 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 7 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 		('int', [])       : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]
# 		('int', ['bool']) : 1 | ['sex']
# 	0.1s = Fit runtime
# 	14 features in original data used to generate 14 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.01 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.15s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric argument of fit()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 80, Val Rows: 20
# Custom Model Type Detected: <class 'autogluon.tabular.models.imodels.imodels_models.RuleFitModel'>
# Custom Model Type Detected: <class 'autogluon.tabular.models.imodels.imodels_models.GreedyTreeModel'>
# Fitting 2 L1 models ...
# Hyperparameter tuning model: RuleFit ...
# /Users/chandan/venvs/autogluon/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,

# %%
leaderboard = predictor.leaderboard(silent=True)
leaderboard

# %% [markdown]
# # test individual model

# %%
# Separate features and labels
X = train_data.drop(columns=[label])
y = train_data[label]
X_test = test_data.drop(columns=[label])
y_test = test_data[label]

# basic model fitting
save_path = 'AutogluonModels'  # specifies folder to store trained models
predictor = TabularPredictor(label=label, path=save_path, verbosity=0).fit(train_data)

# basic model evaluation
predictor = TabularPredictor.load(save_path)  # unnecessary, just demonstrates how to load previously-trained predictor from file
y_pred = predictor.predict(test_data_nolab)
print("Predictions:  \n", y_pred)
perf = predictor.evaluate_predictions(y_true=y_test, y_pred=y_pred, auxiliary_metrics=True)

predictor.leaderboard(test_data, silent=True)
