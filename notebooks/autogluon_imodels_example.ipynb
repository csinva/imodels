# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas as pd
from autogluon.tabular import TabularDataset, TabularPredictor

# %% [markdown]
# **load data**

# %%
# train data
train_data = TabularDataset('https://autogluon.s3.amazonaws.com/datasets/Inc/train.csv')
subsample_size = 100  # subsample subset of data for faster demo, try setting this to much larger values
train_data = train_data.sample(n=subsample_size, random_state=0)
# train_data.head()

# test data
test_data = TabularDataset('https://autogluon.s3.amazonaws.com/datasets/Inc/test.csv')
label = 'class'
y_test = test_data[label]  # values to predict
test_data_nolab = test_data.drop(columns=[label])  # delete label column to prove we're not cheating
# test_data_nolab.head()
# print("Summary of class variable: \n", train_data[label].describe())

# %% [markdown]
# # Fit models using interpretable preset

# %% [markdown]
# **fit using interpretable preset**

# %%
from autogluon.tabular import TabularDataset, TabularPredictor

predictor = TabularPredictor(label=label).fit(train_data, presets='interpretable', time_limit=8, verbosity=2)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20211206_002953/"
# Presets specified: ['interpretable']
# Beginning AutoGluon training ... Time limit = 8s
# AutoGluon will save models to "AutogluonModels/ag-20211206_002953/"
# AutoGluon Version:  0.3.2b20211202
# Python Version:     3.7.0
# Operating System:   Darwin
# Train Data Rows:    100
# Train Data Columns: 14
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [' >50K', ' <=50K']
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 =  >50K, class 0 =  <=50K
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive ( >50K) vs negative ( <=50K) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6626.65 MB
# 	Train Data (Original)  Memory Usage: 0.06 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('int', [])    : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]
# 		('object', []) : 8 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 7 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 		('int', [])       : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]
# 		('int', ['bool']) : 1 | ['sex']
# 	0.1s = Fit runtime
# 	14 features in original data used to generate 14 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.01 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.14s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric argument of fit()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 80, Val Rows: 20
# Fitting 11 L1 models ...
# Fitting model: RuleFit ... Training model for up to 7.86s of the 7.86s of remaining time.
# <class 'imodels.rule_set.rule_fit.RuleFitClassifier'> {'random_state': 0, 'max_rules': 7}
# 	0.75	 = Validation score   (accuracy)
# 	1.47s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: RuleFit_2 ... Training model for up to 6.36s of the 6.36s of remaining time.
# <class 'imodels.rule_set.rule_fit.RuleFitClassifier'> {'random_state': 0, 'max_rules': 15}
# 	0.75	 = Validation score   (accuracy)
# 	0.51s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RuleFit_3 ... Training model for up to 5.82s of the 5.82s of remaining time.
# <class 'imodels.rule_set.rule_fit.RuleFitClassifier'> {'random_state': 0, 'max_rules': 30}
# 	0.75	 = Validation score   (accuracy)
# 	0.54s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: GreedyTree ... Training model for up to 5.27s of the 5.27s of remaining time.
# 	0.85	 = Validation score   (accuracy)
# 	0.02s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: OptimalRuleList ... Training model for up to 5.23s of the 5.22s of remaining time.
# 	0.75	 = Validation score   (accuracy)
# 	0.08s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: OptimalRuleList_2 ... Training model for up to 5.14s of the 5.14s of remaining time.
# 	0.75	 = Validation score   (accuracy)
# 	0.09s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: OptimalRuleList_3 ... Training model for up to 5.04s of the 5.04s of remaining time.
# <class 'imodels.tree.cart_wrapper.GreedyTreeClassifier'> {'random_state': 0}
# <class 'imodels.rule_list.corels_wrapper.OptimalRuleListClassifier'> {'random_state': 0, 'c': 0.001}
# <class 'imodels.rule_list.corels_wrapper.OptimalRuleListClassifier'> {'random_state': 0, 'c': 0.01}
# 	0.75	 = Validation score   (accuracy)
# 	0.02s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: OptimalRuleList_4 ... Training model for up to 5.0s of the 5.0s of remaining time.
# 	0.75	 = Validation score   (accuracy)
# 	0.02s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: OptimalTree ... Training model for up to 4.96s of the 4.96s of remaining time.
# 	Warning: Exception caused OptimalTree to fail during training... Skipping this model.
# 		__init__() got an unexpected keyword argument 'random_state'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/Users/chandan/rules/autogluon/core/src/autogluon/core/trainer/abstract_trainer.py", line 978, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, **model_fit_kwargs)
#   File "/Users/chandan/rules/autogluon/core/src/autogluon/core/trainer/abstract_trainer.py", line 936, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, **model_fit_kwargs)
#   File "/Users/chandan/rules/autogluon/core/src/autogluon/core/models/abstract/abstract_model.py", line 525, in fit
#     out = self._fit(**kwargs)
#   File "/Users/chandan/rules/autogluon/tabular/src/autogluon/tabular/models/imodels/imodels_models.py", line 63, in _fit
#     self.model = model_cls(**params)
# TypeError: __init__() got an unexpected keyword argument 'random_state'
# Fitting model: BoostedRules ... Training model for up to 4.93s of the 4.93s of remaining time.
# 	0.75	 = Validation score   (accuracy)
# 	0.03s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: BoostedRules_2 ... Training model for up to 4.89s of the 4.88s of remaining time.
# 	0.75	 = Validation score   (accuracy)
# 	0.04s	 = Training   runtime
# 	0.01s	 = Validation runtime
# <class 'imodels.rule_list.corels_wrapper.OptimalRuleListClassifier'> {'random_state': 0, 'c': 0.1}
# <class 'imodels.rule_list.corels_wrapper.OptimalRuleListClassifier'> {'random_state': 0, 'c': 1.0}
# <class 'imodels.tree.gosdt.pygosdt.OptimalTreeClassifier'> {'random_state': 0}
# <class 'imodels.rule_set.boosted_rules.BoostedRulesClassifier'> {'random_state': 0, 'n_estimators': 5}
# <class 'imodels.rule_set.boosted_rules.BoostedRulesClassifier'> {'random_state': 0, 'n_estimators': 10}
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 7.86s of the 4.69s of remaining time.
# 	0.85	 = Validation score   (accuracy)
# 	0.23s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 3.56s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20211206_002953/")

# %%
predictor.leaderboard(silent=True)
# Out:
#                  model  score_val  pred_time_val  fit_time  \
# 0           GreedyTree       0.85       0.015331  0.026289
# 1  WeightedEnsemble_L2       0.85       0.023443  0.229514
# 2            RuleFit_3       0.75       0.012083  0.986410
# 3              RuleFit       0.75       0.044963  5.353768
# 4            RuleFit_2       0.75       0.061943  1.158727
#
#    pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                0.015331           0.026289            1       True
# 1                0.008112           0.203225            2       True
# 2                0.012083           0.986410            1       True
# 3                0.044963           5.353768            1       True
# 4                0.061943           1.158727            1       True
#
#    fit_order
# 0          4
# 1          5
# 2          3
# 3          1
# 4          2

# %%
predictor.interpretable_models_summary()
# Out:
#                 model_types  model_performance  complexity  \
# GreedyTree  GreedyTreeModel               0.85         5.0
# RuleFit_3      RuleFitModel               0.75         0.0
# RuleFit        RuleFitModel               0.75        16.0
# RuleFit_2      RuleFitModel               0.75        16.0
#
#                      model_best  \
# GreedyTree  WeightedEnsemble_L2
# RuleFit_3   WeightedEnsemble_L2
# RuleFit     WeightedEnsemble_L2
# RuleFit_2   WeightedEnsemble_L2
#
#                                                   model_paths  \
# GreedyTree  AutogluonModels/ag-20211205_234412/models/Gree...
# RuleFit_3   AutogluonModels/ag-20211205_234412/models/Rule...
# RuleFit     AutogluonModels/ag-20211205_234412/models/Rule...
# RuleFit_2   AutogluonModels/ag-20211205_234412/models/Rule...
#
#             model_fit_times  model_pred_times  num_bag_folds  max_stack_level  \
# GreedyTree         0.026289          0.015331              0                2
# RuleFit_3          0.986410          0.012083              0                2
# RuleFit            5.353768          0.044963              0                2
# RuleFit_2          1.158727          0.061943              0                2
#
#             num_classes                     model_hyperparams
# GreedyTree            2                   {'random_state': 0}
# RuleFit_3             2  {'random_state': 0, 'max_rules': 30}
# RuleFit               2   {'random_state': 0, 'max_rules': 7}
# RuleFit_2             2  {'random_state': 0, 'max_rules': 15}

# %%
predictor.print_interpretable_rules() # automatically selects a model (here, RuleList)
# Out:
# GreedyTree:
# |--- relationship_0 <= 0.50
# |   |--- relationship_5 <= 0.50
# |   |   |--- relationship_2 <= 0.50
# |   |   |   |--- weights: [40.00, 0.00] class: 0
# |   |   |--- relationship_2 >  0.50
# |   |   |   |--- race_2 <= 0.50
# |   |   |   |   |--- weights: [0.00, 1.00] class: 1
# |   |   |   |--- race_2 >  0.50
# |   |   |   |   |--- weights: [1.00, 0.00] class: 0
# |   |--- relationship_5 >  0.50
# |   |   |--- weights: [4.00, 4.00] class: 0
# |--- relationship_0 >  0.50
# |   |--- race_2 <= 0.50
# |   |   |--- weights: [1.00, 0.00] class: 0
# |   |--- race_2 >  0.50
# |   |   |--- weights: [13.00, 16.00] class: 1

# %%
for model_name in ['RuleList', 'BoostedRules', 'RuleFit', 'GreedyTree', 'OptimalTree']:
    predictor.print_interpretable_rules(model_name=model_name)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/01/fl5q4n5547v1g4z0hw_v_mrc0000gn/T/ipykernel_72423/1247643688.py in <module>
#       1 for model_name in ['RuleList', 'BoostedRules', 'RuleFit', 'GreedyTree', 'OptimalTree']:
# ----> 2     predictor.print_interpretable_rules(model_name=model_name)
#       3
#
# ~/rules/autogluon/tabular/src/autogluon/tabular/predictor/predictor.py in print_interpretable_rules(self, complexity_threshold, model_name)
#    2995                 summaries_filtered = summaries
#    2996             model_name = summaries_filtered.index.values[0]  # best model is at top
# -> 2997         agmodel = self._learner.load_trainer().load_model(model_name)
#    2998         imodel = agmodel.model
#    2999         print(imodel)
#
# ~/rules/autogluon/core/src/autogluon/core/trainer/abstract_trainer.py in load_model(self, model_name, path, model_type)
#     837         else:
#     838             if path is None:
# --> 839                 path = self.get_model_attribute(model=model_name, attribute='path')
#     840             if model_type is None:
#     841                 model_type = self.get_model_attribute(model=model_name, attribute='type')
#
# ~/rules/autogluon/core/src/autogluon/core/trainer/abstract_trainer.py in get_model_attribute(self, model, attribute)
#    1670         if not isinstance(model, str):
#    1671             model = model.name
# -> 1672         return self.model_graph.nodes[model][attribute]
#    1673
#    1674     def set_model_attribute(self, model, attribute: str, val):
#
# ~/venvs/autogluon/lib/python3.7/site-packages/networkx/classes/reportviews.py in __getitem__(self, n)
#     191                 f"try list(G.nodes)[{n.start}:{n.stop}:{n.step}]"
#     192             )
# --> 193         return self._nodes[n]
#     194
#     195     # Set methods
#
# KeyError: 'RuleList'

# %% [markdown]
# **fit custom model once (could also include other default models here)**

# %%
from autogluon.tabular.models import RuleFitModel, GreedyTreeModel, CorelsRuleListModel, \
  BayesianRuleSetModel, GlobalSparseTreeModel, BoostedRulesModel

# hyperparams = get_hyperparameter_config('default') # get all default hyperparams for various models
custom_hyperparameters = {
#     RuleFitModel: [{}, {'max_rules': 4}], # empty brackets are dfeault hyperparams
#     GreedyTreeModel: [{}],
    GlobalSparseTreeModel: [{}],
#     BoostedRulesModel: [{}],
#     CorelsRuleListModel: [{}]
}  # Train 3 CustomRandomForestModel with different hyperparameters
predictor = TabularPredictor(label=label).fit(train_data, hyperparameters=custom_hyperparameters, verbosity=2)

# %% [markdown]
# # tune custom models

# %%
from autogluon.core.space import Categorical, Int, Real
from autogluon.tabular.configs.hyperparameter_configs import get_hyperparameter_config

custom_hyperparameters_hpo = {
    RuleFitModel: {
        'tree_size': Int(lower=5, upper=30),
        'max_rules': Int(lower=2, upper=15),
    },
    GreedyTreeModel: {
        'max_leaf_nodes': Int(lower=2, upper=30),
        'ccp_alpha': Real(lower=0, upper=5),
    }
}
# Hyperparameter tune CustomRandomForestModel for 20 seconds
predictor = TabularPredictor(label=label).fit(train_data,
                                              hyperparameters=custom_hyperparameters_hpo,
                                              hyperparameter_tune_kwargs='auto',  # enables HPO
                                              time_limit=60)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/01/fl5q4n5547v1g4z0hw_v_mrc0000gn/T/ipykernel_35857/4155905243.py in <module>
#       3
#       4 custom_hyperparameters_hpo = {
# ----> 5     RuleFitModel: {
#       6         'tree_size': Int(lower=5, upper=30),
#       7         'max_rules': Int(lower=2, upper=15),
#
# NameError: name 'RuleFitModel' is not defined

# %%
leaderboard = predictor.leaderboard(silent=True)
leaderboard
# Out:
#                           model  score_val  pred_time_val  fit_time  \
# 0           WeightedEnsemble_L2       0.86       0.845247  7.283947
# 1               RuleFitModel/T0       0.84       0.825545  7.034827
# 2    GreedyDecisionTreeModel/T0       0.73       0.003500  0.010717
# 3    GreedyDecisionTreeModel/T1       0.73       0.003528  0.010104
# 4    GreedyDecisionTreeModel/T4       0.73       0.003746  0.011251
# 5    GreedyDecisionTreeModel/T7       0.73       0.003767  0.011640
# 6    GreedyDecisionTreeModel/T2       0.73       0.003849  0.010320
# 7   GreedyDecisionTreeModel/T10       0.73       0.003855  0.011145
# 8   GreedyDecisionTreeModel/T21       0.73       0.003873  0.012025
# 9   GreedyDecisionTreeModel/T17       0.73       0.003901  0.011856
# 10  GreedyDecisionTreeModel/T14       0.73       0.003919  0.011541
# 11  GreedyDecisionTreeModel/T20       0.73       0.003968  0.012003
# 12   GreedyDecisionTreeModel/T5       0.73       0.004046  0.011240
# 13  GreedyDecisionTreeModel/T26       0.73       0.004053  0.011001
# 14  GreedyDecisionTreeModel/T13       0.73       0.004146  0.013156
# 15   GreedyDecisionTreeModel/T6       0.73       0.004199  0.017143
# 16  GreedyDecisionTreeModel/T18       0.73       0.004218  0.011898
# 17  GreedyDecisionTreeModel/T32       0.73       0.004231  0.012238
# 18  GreedyDecisionTreeModel/T19       0.73       0.004239  0.011224
# 19  GreedyDecisionTreeModel/T12       0.73       0.004271  0.011848
# 20   GreedyDecisionTreeModel/T9       0.73       0.004364  0.012362
# 21  GreedyDecisionTreeModel/T23       0.73       0.004389  0.012608
# 22  GreedyDecisionTreeModel/T11       0.73       0.004411  0.012325
# 23  GreedyDecisionTreeModel/T31       0.73       0.004501  0.013461
# 24  GreedyDecisionTreeModel/T29       0.73       0.004507  0.014903
# 25   GreedyDecisionTreeModel/T3       0.73       0.004515  0.011620
# 26  GreedyDecisionTreeModel/T22       0.73       0.004644  0.013042
# 27  GreedyDecisionTreeModel/T33       0.73       0.004704  0.014203
# 28  GreedyDecisionTreeModel/T25       0.73       0.004848  0.012327
# 29  GreedyDecisionTreeModel/T28       0.73       0.004983  0.013753
# 30  GreedyDecisionTreeModel/T24       0.73       0.004991  0.011736
# 31  GreedyDecisionTreeModel/T15       0.73       0.005093  0.014280
# 32  GreedyDecisionTreeModel/T34       0.73       0.005168  0.013557
# 33  GreedyDecisionTreeModel/T16       0.73       0.005318  0.014733
# 34  GreedyDecisionTreeModel/T27       0.73       0.005586  0.014985
# 35   GreedyDecisionTreeModel/T8       0.73       0.005911  0.013724
# 36  GreedyDecisionTreeModel/T42       0.73       0.006588  0.020431
# 37  GreedyDecisionTreeModel/T36       0.73       0.007047  0.019460
# 38  GreedyDecisionTreeModel/T37       0.73       0.007605  0.019927
# 39  GreedyDecisionTreeModel/T30       0.73       0.007644  0.021324
# 40  GreedyDecisionTreeModel/T40       0.73       0.008634  0.032559
# 41  GreedyDecisionTreeModel/T38       0.73       0.009390  0.023846
# 42  GreedyDecisionTreeModel/T35       0.73       0.009818  0.021813
# 43  GreedyDecisionTreeModel/T39       0.73       0.012734  0.076272
# 44  GreedyDecisionTreeModel/T41       0.73       0.023023  0.041929
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.000565           0.195108            2       True
# 1                 0.825545           7.034827            1       True
# 2                 0.003500           0.010717            1       True
# 3                 0.003528           0.010104            1       True
# 4                 0.003746           0.011251            1       True
# 5                 0.003767           0.011640            1       True
# 6                 0.003849           0.010320            1       True
# 7                 0.003855           0.011145            1       True
# 8                 0.003873           0.012025            1       True
# 9                 0.003901           0.011856            1       True
# 10                0.003919           0.011541            1       True
# 11                0.003968           0.012003            1       True
# 12                0.004046           0.011240            1       True
# 13                0.004053           0.011001            1       True
# 14                0.004146           0.013156            1       True
# 15                0.004199           0.017143            1       True
# 16                0.004218           0.011898            1       True
# 17                0.004231           0.012238            1       True
# 18                0.004239           0.011224            1       True
# 19                0.004271           0.011848            1       True
# 20                0.004364           0.012362            1       True
# 21                0.004389           0.012608            1       True
# 22                0.004411           0.012325            1       True
# 23                0.004501           0.013461            1       True
# 24                0.004507           0.014903            1       True
# 25                0.004515           0.011620            1       True
# 26                0.004644           0.013042            1       True
# 27                0.004704           0.014203            1       True
# 28                0.004848           0.012327            1       True
# 29                0.004983           0.013753            1       True
# 30                0.004991           0.011736            1       True
# 31                0.005093           0.014280            1       True
# 32                0.005168           0.013557            1       True
# 33                0.005318           0.014733            1       True
# 34                0.005586           0.014985            1       True
# 35                0.005911           0.013724            1       True
# 36                0.006588           0.020431            1       True
# 37                0.007047           0.019460            1       True
# 38                0.007605           0.019927            1       True
# 39                0.007644           0.021324            1       True
# 40                0.008634           0.032559            1       True
# 41                0.009390           0.023846            1       True
# 42                0.009818           0.021813            1       True
# 43                0.012734           0.076272            1       True
# 44                0.023023           0.041929            1       True
#
#     fit_order
# 0          45
# 1           1
# 2           2
# 3           3
# 4           6
# 5           9
# 6           4
# 7          12
# 8          23
# 9          19
# 10         16
# 11         22
# 12          7
# 13         28
# 14         15
# 15          8
# 16         20
# 17         34
# 18         21
# 19         14
# 20         11
# 21         25
# 22         13
# 23         33
# 24         31
# 25          5
# 26         24
# 27         35
# 28         27
# 29         30
# 30         26
# 31         17
# 32         36
# 33         18
# 34         29
# 35         10
# 36         44
# 37         38
# 38         39
# 39         32
# 40         42
# 41         40
# 42         37
# 43         41
# 44         43

# %% [markdown]
# # test individual model

# %%
# Separate features and labels
X = train_data.drop(columns=[label])
y = train_data[label]
X_test = test_data.drop(columns=[label])
y_test = test_data[label]

# basic model fitting
save_path = 'AutogluonModels'  # specifies folder to store trained models
predictor = TabularPredictor(label=label, path=save_path, verbosity=0).fit(train_data)

# basic model evaluation
predictor = TabularPredictor.load(save_path)  # unnecessary, just demonstrates how to load previously-trained predictor from file
y_pred = predictor.predict(test_data_nolab)
print("Predictions:  \n", y_pred)
perf = predictor.evaluate_predictions(y_true=y_test, y_pred=y_pred, auxiliary_metrics=True)

predictor.leaderboard(test_data, silent=True)
# Out:
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [' >50K', ' <=50K']
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 =  >50K, class 0 =  <=50K
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive ( >50K) vs negative ( <=50K) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    7225.86 MB
# 	Train Data (Original)  Memory Usage: 0.3 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('int', [])    : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]
# 		('object', []) : 8 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 7 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 		('int', [])       : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]
# 		('int', ['bool']) : 1 | ['sex']
# 	0.2s = Fit runtime
# 	14 features in original data used to generate 14 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.04 MB (0.0% of available memory)
# Labels cleaned: {' <=50K': 0, ' >50K': 1}
# inferred problem type as: binary
# Cleaned label values:
#        age  fnlwgt  education-num  sex  capital-gain  capital-loss  \
# 6118    51   39264             10    0             0             0
# 23204   58   51662              6    0             0             0
# 29590   40  326310             10    1             0             0
# 18116   37  222450              9    1             0          2339
# 33964   62  109190             13    1         15024             0
#
#        hours-per-week workclass education marital-status occupation  \
# 6118               40         3        13              1          3
# 23204               8         3         0              1          7
# 29590              44         3        13              1          2
# 18116              40         3        10              3         10
# 33964              40         3         8              1          3
#
#       relationship race native-country
# 6118             5    4             14
# 23204            5    4             14
# 29590            0    4             14
# 18116            1    4            NaN
# 33964            0    4             14
