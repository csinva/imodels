# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas as pd
from autogluon.tabular import TabularDataset, TabularPredictor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/01/fl5q4n5547v1g4z0hw_v_mrc0000gn/T/ipykernel_33057/3340959735.py in <module>
#       3 import numpy as np
#       4 import pandas as pd
# ----> 5 from autogluon.tabular import TabularDataset, TabularPredictor
#
# ModuleNotFoundError: No module named 'autogluon'

# %% [markdown]
# **load data**

# %%
# train data
train_data = TabularDataset('https://autogluon.s3.amazonaws.com/datasets/Inc/train.csv')
subsample_size = 100  # subsample subset of data for faster demo, try setting this to much larger values
train_data = train_data.sample(n=subsample_size, random_state=0)
# train_data.head()

# test data
test_data = TabularDataset('https://autogluon.s3.amazonaws.com/datasets/Inc/test.csv')
label = 'class'
y_test = test_data[label]  # values to predict
test_data_nolab = test_data.drop(columns=[label])  # delete label column to prove we're not cheating
# test_data_nolab.head()
# print("Summary of class variable: \n", train_data[label].describe())

# %% [markdown]
# # Fit models using interpretable preset

# %% [markdown]
# **fit using interpretable preset**

# %%
predictor = TabularPredictor(label=label).fit(train_data, presets='interpretable', time_limit=8, verbosity=2)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20211206_023939/"
# Presets specified: ['interpretable']
# Beginning AutoGluon training ... Time limit = 8s
# AutoGluon will save models to "AutogluonModels/ag-20211206_023939/"
# AutoGluon Version:  0.3.2b20211202
# Python Version:     3.7.0
# Operating System:   Darwin
# Train Data Rows:    100
# Train Data Columns: 14
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [' >50K', ' <=50K']
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 =  >50K, class 0 =  <=50K
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive ( >50K) vs negative ( <=50K) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6887.51 MB
# 	Train Data (Original)  Memory Usage: 0.06 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('int', [])    : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]
# 		('object', []) : 8 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 7 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 		('int', [])       : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]
# 		('int', ['bool']) : 1 | ['sex']
# 	0.1s = Fit runtime
# 	14 features in original data used to generate 14 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.01 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.16s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric argument of fit()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 80, Val Rows: 20
# Fitting 10 L1 models ...
# Fitting model: RuleFit ... Training model for up to 7.84s of the 7.83s of remaining time.
# /Users/chandan/venvs/autogluon/lib/python3.7/site-packages/sklearn/utils/validation.py:617: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# /Users/chandan/venvs/autogluon/lib/python3.7/site-packages/sklearn/utils/validation.py:617: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# 	0.75	 = Validation score   (accuracy)
# 	1.66s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RuleFit_2 ... Training model for up to 6.16s of the 6.15s of remaining time.
# /Users/chandan/venvs/autogluon/lib/python3.7/site-packages/sklearn/utils/validation.py:617: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# /Users/chandan/venvs/autogluon/lib/python3.7/site-packages/sklearn/utils/validation.py:617: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# 	0.75	 = Validation score   (accuracy)
# 	0.76s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RuleFit_3 ... Training model for up to 5.38s of the 5.37s of remaining time.
# /Users/chandan/venvs/autogluon/lib/python3.7/site-packages/sklearn/utils/validation.py:617: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# /Users/chandan/venvs/autogluon/lib/python3.7/site-packages/sklearn/utils/validation.py:617: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# 	0.75	 = Validation score   (accuracy)
# 	0.75s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: GreedyTree ... Training model for up to 4.55s of the 4.55s of remaining time.
# /Users/chandan/venvs/autogluon/lib/python3.7/site-packages/sklearn/utils/validation.py:617: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# /Users/chandan/venvs/autogluon/lib/python3.7/site-packages/sklearn/utils/validation.py:617: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# 	0.8	 = Validation score   (accuracy)
# 	0.03s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: OptimalRuleList ... Training model for up to 4.51s of the 4.51s of remaining time.
# 	Warning: Exception caused OptimalRuleList to fail during training... Skipping this model.
# 		The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/Users/chandan/rules/autogluon/core/src/autogluon/core/trainer/abstract_trainer.py", line 978, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, **model_fit_kwargs)
#   File "/Users/chandan/rules/autogluon/core/src/autogluon/core/trainer/abstract_trainer.py", line 936, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, **model_fit_kwargs)
#   File "/Users/chandan/rules/autogluon/core/src/autogluon/core/models/abstract/abstract_model.py", line 525, in fit
#     out = self._fit(**kwargs)
#   File "/Users/chandan/rules/autogluon/tabular/src/autogluon/tabular/models/imodels/imodels_models.py", line 50, in _fit
#     self.model.fit(X, y, feature_names=X.columns.values.tolist())
#   File "/Users/chandan/rules/imodels/imodels/rule_list/corels_wrapper.py", line 121, in fit
#     super().fit(X, y, features=feature_names, prediction_name=prediction_name)
#   File "/Users/chandan/venvs/autogluon/lib/python3.7/site-packages/corels/corels.py", line 172, in fit
#     if features:
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# Fitting model: OptimalRuleList_2 ... Training model for up to 4.45s of the 4.45s of remaining time.
# 	Warning: Exception caused OptimalRuleList_2 to fail during training... Skipping this model.
# 		The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/Users/chandan/rules/autogluon/core/src/autogluon/core/trainer/abstract_trainer.py", line 978, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, **model_fit_kwargs)
#   File "/Users/chandan/rules/autogluon/core/src/autogluon/core/trainer/abstract_trainer.py", line 936, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, **model_fit_kwargs)
#   File "/Users/chandan/rules/autogluon/core/src/autogluon/core/models/abstract/abstract_model.py", line 525, in fit
#     out = self._fit(**kwargs)
#   File "/Users/chandan/rules/autogluon/tabular/src/autogluon/tabular/models/imodels/imodels_models.py", line 50, in _fit
#     self.model.fit(X, y, feature_names=X.columns.values.tolist())
#   File "/Users/chandan/rules/imodels/imodels/rule_list/corels_wrapper.py", line 121, in fit
#     super().fit(X, y, features=feature_names, prediction_name=prediction_name)
#   File "/Users/chandan/venvs/autogluon/lib/python3.7/site-packages/corels/corels.py", line 172, in fit
#     if features:
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# Fitting model: OptimalRuleList_3 ... Training model for up to 4.41s of the 4.4s of remaining time.
# 	Warning: Exception caused OptimalRuleList_3 to fail during training... Skipping this model.
# 		The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/Users/chandan/rules/autogluon/core/src/autogluon/core/trainer/abstract_trainer.py", line 978, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, **model_fit_kwargs)
#   File "/Users/chandan/rules/autogluon/core/src/autogluon/core/trainer/abstract_trainer.py", line 936, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, **model_fit_kwargs)
#   File "/Users/chandan/rules/autogluon/core/src/autogluon/core/models/abstract/abstract_model.py", line 525, in fit
#     out = self._fit(**kwargs)
#   File "/Users/chandan/rules/autogluon/tabular/src/autogluon/tabular/models/imodels/imodels_models.py", line 50, in _fit
#     self.model.fit(X, y, feature_names=X.columns.values.tolist())
#   File "/Users/chandan/rules/imodels/imodels/rule_list/corels_wrapper.py", line 121, in fit
#     super().fit(X, y, features=feature_names, prediction_name=prediction_name)
#   File "/Users/chandan/venvs/autogluon/lib/python3.7/site-packages/corels/corels.py", line 172, in fit
#     if features:
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# Fitting model: OptimalRuleList_4 ... Training model for up to 4.35s of the 4.35s of remaining time.
# 	Warning: Exception caused OptimalRuleList_4 to fail during training... Skipping this model.
# 		The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/Users/chandan/rules/autogluon/core/src/autogluon/core/trainer/abstract_trainer.py", line 978, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, **model_fit_kwargs)
#   File "/Users/chandan/rules/autogluon/core/src/autogluon/core/trainer/abstract_trainer.py", line 936, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, **model_fit_kwargs)
#   File "/Users/chandan/rules/autogluon/core/src/autogluon/core/models/abstract/abstract_model.py", line 525, in fit
#     out = self._fit(**kwargs)
#   File "/Users/chandan/rules/autogluon/tabular/src/autogluon/tabular/models/imodels/imodels_models.py", line 50, in _fit
#     self.model.fit(X, y, feature_names=X.columns.values.tolist())
#   File "/Users/chandan/rules/imodels/imodels/rule_list/corels_wrapper.py", line 121, in fit
#     super().fit(X, y, features=feature_names, prediction_name=prediction_name)
#   File "/Users/chandan/venvs/autogluon/lib/python3.7/site-packages/corels/corels.py", line 172, in fit
#     if features:
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# Fitting model: BoostedRules ... Training model for up to 4.29s of the 4.29s of remaining time.
# /Users/chandan/venvs/autogluon/lib/python3.7/site-packages/sklearn/utils/validation.py:617: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# /Users/chandan/venvs/autogluon/lib/python3.7/site-packages/sklearn/utils/validation.py:617: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# 	0.8	 = Validation score   (accuracy)
# 	0.04s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: BoostedRules_2 ... Training model for up to 4.23s of the 4.23s of remaining time.
# /Users/chandan/venvs/autogluon/lib/python3.7/site-packages/sklearn/utils/validation.py:617: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# /Users/chandan/venvs/autogluon/lib/python3.7/site-packages/sklearn/utils/validation.py:617: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# 	0.8	 = Validation score   (accuracy)
# 	0.04s	 = Training   runtime
# 	0.02s	 = Validation runtime
# /Users/chandan/venvs/autogluon/lib/python3.7/site-packages/sklearn/utils/validation.py:617: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# /Users/chandan/venvs/autogluon/lib/python3.7/site-packages/sklearn/utils/validation.py:617: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# /Users/chandan/venvs/autogluon/lib/python3.7/site-packages/sklearn/utils/validation.py:617: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# /Users/chandan/venvs/autogluon/lib/python3.7/site-packages/sklearn/utils/validation.py:617: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# /Users/chandan/venvs/autogluon/lib/python3.7/site-packages/sklearn/utils/validation.py:617: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# /Users/chandan/venvs/autogluon/lib/python3.7/site-packages/sklearn/utils/validation.py:617: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 7.84s of the 4.0s of remaining time.
# 	0.8	 = Validation score   (accuracy)
# 	0.16s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 4.2s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20211206_023939/")

# %%
predictor.leaderboard(silent=True)
# Out:
#                  model  score_val  pred_time_val  fit_time  \
# 0           GreedyTree       0.80       0.015613  0.027856
# 1  WeightedEnsemble_L2       0.80       0.016004  0.190456
# 2       BoostedRules_2       0.80       0.017906  0.042740
# 3         BoostedRules       0.80       0.019046  0.035654
# 4              RuleFit       0.75       0.012949  1.664366
# 5            RuleFit_2       0.75       0.013417  0.763767
# 6            RuleFit_3       0.75       0.062435  0.754747
#
#    pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                0.015613           0.027856            1       True
# 1                0.000391           0.162600            2       True
# 2                0.017906           0.042740            1       True
# 3                0.019046           0.035654            1       True
# 4                0.012949           1.664366            1       True
# 5                0.013417           0.763767            1       True
# 6                0.062435           0.754747            1       True
#
#    fit_order
# 0          4
# 1          7
# 2          6
# 3          5
# 4          1
# 5          2
# 6          3

# %%
predictor.interpretable_models_summary()
# Out:
#                       model_types  model_performance  complexity  \
# GreedyTree        GreedyTreeModel               0.80         8.0
# BoostedRules    BoostedRulesModel               0.80        10.0
# BoostedRules_2  BoostedRulesModel               0.80        20.0
# RuleFit              RuleFitModel               0.75         0.0
# RuleFit_2            RuleFitModel               0.75         0.0
# RuleFit_3            RuleFitModel               0.75        53.0
#
#                          model_best  \
# GreedyTree      WeightedEnsemble_L2
# BoostedRules    WeightedEnsemble_L2
# BoostedRules_2  WeightedEnsemble_L2
# RuleFit         WeightedEnsemble_L2
# RuleFit_2       WeightedEnsemble_L2
# RuleFit_3       WeightedEnsemble_L2
#
#                                                       model_paths  \
# GreedyTree      AutogluonModels/ag-20211206_023939/models/Gree...
# BoostedRules    AutogluonModels/ag-20211206_023939/models/Boos...
# BoostedRules_2  AutogluonModels/ag-20211206_023939/models/Boos...
# RuleFit         AutogluonModels/ag-20211206_023939/models/Rule...
# RuleFit_2       AutogluonModels/ag-20211206_023939/models/Rule...
# RuleFit_3       AutogluonModels/ag-20211206_023939/models/Rule...
#
#                 model_fit_times  model_pred_times  num_bag_folds  \
# GreedyTree             0.027856          0.015613              0
# BoostedRules           0.035654          0.019046              0
# BoostedRules_2         0.042740          0.017906              0
# RuleFit                1.664366          0.012949              0
# RuleFit_2              0.763767          0.013417              0
# RuleFit_3              0.754747          0.062435              0
#
#                 max_stack_level  num_classes  \
# GreedyTree                    2            2
# BoostedRules                  2            2
# BoostedRules_2                2            2
# RuleFit                       2            2
# RuleFit_2                     2            2
# RuleFit_3                     2            2
#
#                                         model_hyperparams
# GreedyTree      {'random_state': 0, 'max_leaf_nodes': 20}
# BoostedRules       {'random_state': 0, 'n_estimators': 5}
# BoostedRules_2    {'random_state': 0, 'n_estimators': 10}
# RuleFit               {'random_state': 0, 'max_rules': 7}
# RuleFit_2            {'random_state': 0, 'max_rules': 12}
# RuleFit_3            {'random_state': 0, 'max_rules': 20}

# %%
predictor.print_interpretable_rules() # automatically selects a model (here, RuleList)
# Out:
# GreedyTree:
# |--- marital-status_1.0 <= 0.50
# |   |--- weights: [42.00, 0.00] class: 0
# |--- marital-status_1.0 >  0.50
# |   |--- age <= 36.00
# |   |   |--- weights: [10.00, 0.00] class: 0
# |   |--- age >  36.00
# |   |   |--- occupation_5.0 <= 0.50
# |   |   |   |--- fnlwgt <= 211963.50
# |   |   |   |   |--- education_0.0 <= 0.50
# |   |   |   |   |   |--- weights: [0.00, 16.00] class: 1
# |   |   |   |   |--- education_0.0 >  0.50
# |   |   |   |   |   |--- weights: [1.00, 0.00] class: 0
# |   |   |   |--- fnlwgt >  211963.50
# |   |   |   |   |--- age <= 55.50
# |   |   |   |   |   |--- hours-per-week <= 50.00
# |   |   |   |   |   |   |--- weights: [0.00, 4.00] class: 1
# |   |   |   |   |   |--- hours-per-week >  50.00
# |   |   |   |   |   |   |--- workclass_4.0 <= 0.50
# |   |   |   |   |   |   |   |--- weights: [2.00, 0.00] class: 0
# |   |   |   |   |   |   |--- workclass_4.0 >  0.50
# |   |   |   |   |   |   |   |--- weights: [0.00, 1.00] class: 1
# |   |   |   |   |--- age >  55.50
# |   |   |   |   |   |--- weights: [2.00, 0.00] class: 0
# |   |   |--- occupation_5.0 >  0.50
# |   |   |   |--- weights: [2.00, 0.00] class: 0

# %%
for model_name in ['RuleFit', 'GreedyTree', 'BoostedRules']: #, 'OptimalTree', 'OptimalRuleList':
    predictor.print_interpretable_rules(model_name=model_name)
# Out:
# RuleFit:
#           rule  coef
#  education-num -0.02
#
# GreedyTree:
# |--- marital-status_1.0 <= 0.50
# |   |--- weights: [42.00, 0.00] class: 0
# |--- marital-status_1.0 >  0.50
# |   |--- age <= 36.00
# |   |   |--- weights: [10.00, 0.00] class: 0
# |   |--- age >  36.00
# |   |   |--- occupation_5.0 <= 0.50
# |   |   |   |--- fnlwgt <= 211963.50
# |   |   |   |   |--- education_0.0 <= 0.50
# |   |   |   |   |   |--- weights: [0.00, 16.00] class: 1
# |   |   |   |   |--- education_0.0 >  0.50
# |   |   |   |   |   |--- weights: [1.00, 0.00] class: 0
# |   |   |   |--- fnlwgt >  211963.50
# |   |   |   |   |--- age <= 55.50
# |   |   |   |   |   |--- hours-per-week <= 50.00
# |   |   |   |   |   |   |--- weights: [0.00, 4.00] class: 1
# |   |   |   |   |   |--- hours-per-week >  50.00
# |   |   |   |   |   |   |--- workclass_4.0 <= 0.50
# |   |   |   |   |   |   |   |--- weights: [2.00, 0.00] class: 0
# |   |   |   |   |   |   |--- workclass_4.0 >  0.50
# |   |   |   |   |   |   |   |--- weights: [0.00, 1.00] class: 1
# |   |   |   |   |--- age >  55.50
# |   |   |   |   |   |--- weights: [2.00, 0.00] class: 0
# |   |   |--- occupation_5.0 >  0.50
# |   |   |   |--- weights: [2.00, 0.00] class: 0
#
# BoostedRules:
# Rule → predicted probability (final prediction is weighted sum of all predictions)
#   If marital-status_1.0 <= 0.5 → 0.47 (weight: 0.65)
#   If marital-status_1.0 > 0.5 → 0.00 (weight: 0.80)
#   If age <= 36.0 → 0.54 (weight: 0.71)
#   If age > 36.0 → 0.00 (weight: 0.40)
#   If age <= 36.0 → 0.47 (weight: 0.40)

# %% [markdown]
# **fit custom model once (could also include other default models here)**

# %%
from autogluon.tabular.models import RuleFitModel, GreedyTreeModel, OptimalRuleListModel, \
  BayesianRuleSetModel, OptimalTreeModel, BoostedRulesModel

# hyperparams = get_hyperparameter_config('default') # get all default hyperparams for various models
custom_hyperparameters = {
#     RuleFitModel: [{}, {'max_rules': 4}], # empty brackets are dfeault hyperparams
#     GreedyTreeModel: [{}],
    OptimalTreeModel: [{}],
#     BoostedRulesModel: [{}],
#     OptimalRuleListModel: [{}]
}  # Train 3 CustomRandomForestModel with different hyperparameters
predictor = TabularPredictor(label=label).fit(train_data, hyperparameters=custom_hyperparameters, verbosity=2)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20211206_024224/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20211206_024224/"
# AutoGluon Version:  0.3.2b20211202
# Python Version:     3.7.0
# Operating System:   Darwin
# Train Data Rows:    100
# Train Data Columns: 14
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [' >50K', ' <=50K']
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 =  >50K, class 0 =  <=50K
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive ( >50K) vs negative ( <=50K) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6845.74 MB
# 	Train Data (Original)  Memory Usage: 0.06 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('int', [])    : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]
# 		('object', []) : 8 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 7 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 		('int', [])       : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]
# 		('int', ['bool']) : 1 | ['sex']
# 	0.1s = Fit runtime
# 	14 features in original data used to generate 14 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.01 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.16s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric argument of fit()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 80, Val Rows: 20
# Custom Model Type Detected: <class 'autogluon.tabular.models.imodels.imodels_models.OptimalTreeModel'>
# Fitting 1 L1 models ...
# Fitting model: OptimalTree ...
# /Users/chandan/rules/imodels/imodels/tree/gosdt/pygosdt.py:127: UserWarning: Should install gosdt extension. On x86_64 linux or macOS: 'pip install gosdt'. On other platforms, see https://github.com/keyan3/GeneralizedOptimalSparseDecisionTrees. Defaulting to Non-optimal DecisionTreeClassifier.
#   "Should install gosdt extension. On x86_64 linux or macOS: "
# /Users/chandan/venvs/autogluon/lib/python3.7/site-packages/sklearn/utils/validation.py:617: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# /Users/chandan/venvs/autogluon/lib/python3.7/site-packages/sklearn/utils/validation.py:617: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# 	0.75	 = Validation score   (accuracy)
# 	0.04s	 = Training   runtime
# 	0.02s	 = Validation runtime
# /Users/chandan/venvs/autogluon/lib/python3.7/site-packages/sklearn/utils/validation.py:617: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# Fitting model: WeightedEnsemble_L2 ...
# 	0.75	 = Validation score   (accuracy)
# 	0.0s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 0.29s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20211206_024224/")

# %% [markdown]
# # tune custom models

# %%
from autogluon.core.space import Categorical, Int, Real
from autogluon.tabular.configs.hyperparameter_configs import get_hyperparameter_config

custom_hyperparameters_hpo = {
    RuleFitModel: {
        'tree_size': Int(lower=5, upper=30),
        'max_rules': Int(lower=2, upper=15),
    },
    GreedyTreeModel: {
        'max_leaf_nodes': Int(lower=2, upper=30),
        'ccp_alpha': Real(lower=0, upper=5),
    }
}
# Hyperparameter tune CustomRandomForestModel for 20 seconds
predictor = TabularPredictor(label=label).fit(train_data,
                                              hyperparameters=custom_hyperparameters_hpo,
                                              hyperparameter_tune_kwargs='auto',  # enables HPO
                                              time_limit=60)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20211206_024230/"
# Warning: hyperparameter tuning is currently experimental and may cause the process to hang.
# Beginning AutoGluon training ... Time limit = 60s
# AutoGluon will save models to "AutogluonModels/ag-20211206_024230/"
# AutoGluon Version:  0.3.2b20211202
# Python Version:     3.7.0
# Operating System:   Darwin
# Train Data Rows:    100
# Train Data Columns: 14
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [' >50K', ' <=50K']
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 =  >50K, class 0 =  <=50K
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive ( >50K) vs negative ( <=50K) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6839.47 MB
# 	Train Data (Original)  Memory Usage: 0.06 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('int', [])    : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]
# 		('object', []) : 8 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 7 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 		('int', [])       : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]
# 		('int', ['bool']) : 1 | ['sex']
# 	0.1s = Fit runtime
# 	14 features in original data used to generate 14 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.01 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.15s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric argument of fit()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 80, Val Rows: 20
# Custom Model Type Detected: <class 'autogluon.tabular.models.imodels.imodels_models.RuleFitModel'>
# Custom Model Type Detected: <class 'autogluon.tabular.models.imodels.imodels_models.GreedyTreeModel'>
# Fitting 2 L1 models ...
# Hyperparameter tuning model: RuleFit ...
# /Users/chandan/venvs/autogluon/lib/python3.7/site-packages/sklearn/utils/validation.py:617: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."

# %%
leaderboard = predictor.leaderboard(silent=True)
leaderboard

# %% [markdown]
# # test individual model

# %%
# Separate features and labels
X = train_data.drop(columns=[label])
y = train_data[label]
X_test = test_data.drop(columns=[label])
y_test = test_data[label]

# basic model fitting
save_path = 'AutogluonModels'  # specifies folder to store trained models
predictor = TabularPredictor(label=label, path=save_path, verbosity=0).fit(train_data)

# basic model evaluation
predictor = TabularPredictor.load(save_path)  # unnecessary, just demonstrates how to load previously-trained predictor from file
y_pred = predictor.predict(test_data_nolab)
print("Predictions:  \n", y_pred)
perf = predictor.evaluate_predictions(y_true=y_test, y_pred=y_pred, auxiliary_metrics=True)

predictor.leaderboard(test_data, silent=True)
# Out:
# 	Warning: Exception caused LightGBMXT to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/chandan/venvs/autogluon/lib/python3.7/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: /Users/chandan/venvs/autogluon/lib/python3.7/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file)
# 	Warning: Exception caused LightGBM to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/chandan/venvs/autogluon/lib/python3.7/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: /Users/chandan/venvs/autogluon/lib/python3.7/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file)
# 	Warning: Exception caused XGBoost to fail during training... Skipping this model.
# 		XGBoost Library (libxgboost.dylib) could not be loaded.
# Likely causes:
#   * OpenMP runtime is not installed (vcomp140.dll or libgomp-1.dll for Windows, libomp.dylib for Mac OSX, libgomp.so for Linux and other UNIX-like OSes). Mac OSX users: Run `brew install libomp` to install OpenMP runtime.
#   * You are running 32-bit Python on a 64-bit OS
# Error message(s): ["dlopen(/Users/chandan/venvs/autogluon/lib/python3.7/site-packages/xgboost/lib/libxgboost.dylib, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib\n  Referenced from: /Users/chandan/venvs/autogluon/lib/python3.7/site-packages/xgboost/lib/libxgboost.dylib\n  Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file)"]
#
# 	Warning: Exception caused NeuralNetMXNet to fail during training (ImportError)... Skipping this model.
# 		Unable to import dependency mxnet. A quick tip is to install via `pip install mxnet --upgrade`, or `pip install mxnet_cu101 --upgrade`
# 	Warning: Exception caused LightGBMLarge to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/chandan/venvs/autogluon/lib/python3.7/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: /Users/chandan/venvs/autogluon/lib/python3.7/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file)
# Predictions:
#  0        <=50K
# 1        <=50K
# 2        <=50K
# 3        <=50K
# 4        <=50K
#          ...
# 9764     <=50K
# 9765     <=50K
# 9766     <=50K
# 9767     <=50K
# 9768     <=50K
# Name: class, Length: 9769, dtype: object
#                  model  score_test  score_val  pred_time_test  pred_time_val  \
# 0       ExtraTreesEntr    0.793326       0.80        0.116670       0.111038
# 1       ExtraTreesGini    0.793019       0.75        0.121069       0.115508
# 2     RandomForestEntr    0.787082       0.70        0.117342       0.110090
# 3     RandomForestGini    0.784727       0.70        0.123659       0.111205
# 4  WeightedEnsemble_L2    0.780326       0.95        0.973099       0.145584
# 5      NeuralNetFastAI    0.779916       0.90        0.846020       0.021884
# 6             CatBoost    0.731498       0.75        0.011916       0.016519
# 7       KNeighborsUnif    0.728324       0.70        0.109672       0.112313
# 8       KNeighborsDist    0.655236       0.65        0.109978       0.106827
#
#    fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0  0.436669                 0.116670                0.111038
# 1  0.605012                 0.121069                0.115508
# 2  0.553712                 0.117342                0.110090
# 3  0.524461                 0.123659                0.111205
# 4  2.943147                 0.005185                0.000354
# 5  1.816362                 0.846020                0.021884
# 6  0.950074                 0.011916                0.016519
# 7  0.006622                 0.109672                0.112313
# 8  0.005025                 0.109978                0.106827
#
#    fit_time_marginal  stack_level  can_infer  fit_order
# 0           0.436669            1       True          7
# 1           0.605012            1       True          6
# 2           0.553712            1       True          4
# 3           0.524461            1       True          3
# 4           0.171686            2       True          9
# 5           1.816362            1       True          8
# 6           0.950074            1       True          5
# 7           0.006622            1       True          1
# 8           0.005025            1       True          2
