# %% [markdown]
# This notebook shows some examples of fitting different models to classification/regression datasets. We start by loading some classifiers / regressors from `imodels`.

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import plot_tree, DecisionTreeClassifier
from sklearn import metrics
import sklearn.preprocessing
import imodels
from imodels.util.data_util import DSET_CLASSIFICATION_KWARGS

print(list(DSET_CLASSIFICATION_KWARGS.keys()))
# installable with: `pip install imodels`
np.random.seed(13)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ['pima_diabetes', 'sonar', 'heart', 'diabetes', 'breast_cancer_recurrence', 'breast_cancer_wisconsin', 'credit_g', 'juvenile', 'compas', 'fico', 'readmission', 'adult', 'csi_pecarn', 'iai_pecarn', 'tbi_pecarn']

# %%
X, y, feature_names = imodels.get_clean_dataset("pima_diabetes")

print("shapes", X.shape, y.shape, "nunique", np.unique(y).size)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=42, test_size=0.2
)

m = sklearn.preprocessing.StandardScaler()
X_train = m.fit_transform(X_train)
X_test = m.transform(X_test)

m = imodels.AutoInterpretableClassifier()
m.fit(X_train, y_train, cv=3)

print("best params", m.est_.best_params_)
print("best score", m.est_.best_score_)
print("best estimator", m.est_.best_estimator_)
print("best estimator params", m.est_.best_estimator_.get_params())
# Out:
# fetching 40715 from openml
# shapes (768, 8) (768,) nunique 2
# /home/chansingh/imodelsx/.venv/lib/python3.11/site-packages/sklearn/datasets/_openml.py:971: UserWarning: Version 1 of dataset pima is inactive, meaning that issues have been found in the dataset. Try using a newer version from this URL: https://api.openml.org/data/v1/download/4965316/pima.arff
#   warn(
# best params {'est': LogisticRegression(C=0.1, l1_ratio=0.5, penalty='elasticnet', solver='saga'), 'est__C': 0.1, 'est__l1_ratio': 0.5}
# best score 0.8267026097959889
# best estimator Pipeline(steps=[('est',
#                  LogisticRegression(C=0.1, l1_ratio=0.5, penalty='elasticnet',
#                                     solver='saga'))])
# best estimator params {'memory': None, 'steps': [('est', LogisticRegression(C=0.1, l1_ratio=0.5, penalty='elasticnet', solver='saga'))], 'verbose': False, 'est': LogisticRegression(C=0.1, l1_ratio=0.5, penalty='elasticnet', solver='saga'), 'est__C': 0.1, 'est__class_weight': None, 'est__dual': False, 'est__fit_intercept': True, 'est__intercept_scaling': 1, 'est__l1_ratio': 0.5, 'est__max_iter': 100, 'est__multi_class': 'auto', 'est__n_jobs': None, 'est__penalty': 'elasticnet', 'est__random_state': None, 'est__solver': 'saga', 'est__tol': 0.0001, 'est__verbose': 0, 'est__warm_start': False}

# %%
df = pd.DataFrame(m.est_.cv_results_).sort_values("rank_test_score")
first_cols = ["rank_test_score", "mean_test_score", "std_test_score"]
df = df[first_cols + [c for c in df.columns if c not in first_cols]].round(3)
# remove std_ cols
df = df[[c for c in df.columns if "std_" not in c]]
df
# Out:
#     rank_test_score  mean_test_score  mean_fit_time  mean_score_time  \
# 4                 1            0.827          0.002            0.001
# 3                 2            0.824          0.002            0.001
# 5                 3            0.823          0.002            0.001
# 8                 4            0.822          0.002            0.001
# 7                 5            0.821          0.002            0.001
# 6                 6            0.821          0.002            0.001
# 10                7            0.820          0.002            0.001
# 9                 8            0.820          0.002            0.001
# 11                9            0.820          0.002            0.001
# 15               10            0.810          2.070            0.046
# 12               11            0.810          0.427            0.014
# 14               12            0.803          0.075            0.007
# 13               13            0.796          7.591            0.074
# 19               14            0.771          0.038            0.002
# 1                15            0.763          0.001            0.001
# 18               16            0.763          0.015            0.002
# 2                17            0.756          0.002            0.001
# 16               18            0.738          0.002            0.001
# 17               19            0.736          0.002            0.001
# 0                20            0.697          0.001            0.002
#
#                                             param_est  \
# 4   LogisticRegression(C=0.1, l1_ratio=0.5, penalt...
# 3   LogisticRegression(C=0.1, l1_ratio=0.5, penalt...
# 5   LogisticRegression(C=0.1, l1_ratio=0.5, penalt...
# 8   LogisticRegression(C=0.1, l1_ratio=0.5, penalt...
# 7   LogisticRegression(C=0.1, l1_ratio=0.5, penalt...
# 6   LogisticRegression(C=0.1, l1_ratio=0.5, penalt...
# 10  LogisticRegression(C=0.1, l1_ratio=0.5, penalt...
# 9   LogisticRegression(C=0.1, l1_ratio=0.5, penalt...
# 11  LogisticRegression(C=0.1, l1_ratio=0.5, penalt...
# 15            TreeGAMClassifier(n_boosting_rounds=10)
# 12                    RuleFitClassifier(max_rules=30)
# 14            TreeGAMClassifier(n_boosting_rounds=10)
# 13                    RuleFitClassifier(max_rules=30)
# 19                       FIGSClassifier(max_rules=12)
# 1                            DecisionTreeClassifier()
# 18                       FIGSClassifier(max_rules=12)
# 2                            DecisionTreeClassifier()
# 16  HSTreeClassifier(est=DecisionTreeClassifier(ma...
# 17  HSTreeClassifier(est=DecisionTreeClassifier(ma...
# 0                            DecisionTreeClassifier()
#
#    param_est__max_leaf_nodes param_est__C param_est__l1_ratio  \
# 4                        NaN          0.1                 0.5
# 3                        NaN          0.1                   0
# 5                        NaN          0.1                   1
# 8                        NaN            1                   1
# 7                        NaN            1                 0.5
# 6                        NaN            1                   0
# 10                       NaN           10                 0.5
# 9                        NaN           10                   0
# 11                       NaN           10                   1
# 15                       NaN          NaN                 NaN
# 12                       NaN          NaN                 NaN
# 14                       NaN          NaN                 NaN
# 13                       NaN          NaN                 NaN
# 19                       NaN          NaN                 NaN
# 1                          5          NaN                 NaN
# 18                       NaN          NaN                 NaN
# 2                         10          NaN                 NaN
# 16                         5          NaN                 NaN
# 17                        10          NaN                 NaN
# 0                          2          NaN                 NaN
#
#    param_est__max_rules param_est__n_estimators param_est__n_boosting_rounds  \
# 4                   NaN                     NaN                          NaN
# 3                   NaN                     NaN                          NaN
# 5                   NaN                     NaN                          NaN
# 8                   NaN                     NaN                          NaN
# 7                   NaN                     NaN                          NaN
# 6                   NaN                     NaN                          NaN
# 10                  NaN                     NaN                          NaN
# 9                   NaN                     NaN                          NaN
# 11                  NaN                     NaN                          NaN
# 15                  NaN                     NaN                          100
# 12                   10                      20                          NaN
# 14                  NaN                     NaN                           10
# 13                  100                      20                          NaN
# 19                   10                     NaN                          NaN
# 1                   NaN                     NaN                          NaN
# 18                    5                     NaN                          NaN
# 2                   NaN                     NaN                          NaN
# 16                  NaN                     NaN                          NaN
# 17                  NaN                     NaN                          NaN
# 0                   NaN                     NaN                          NaN
#
#                                                params  split0_test_score  \
# 4   {'est': LogisticRegression(C=0.1, l1_ratio=0.5...              0.813
# 3   {'est': LogisticRegression(C=0.1, l1_ratio=0.5...              0.814
# 5   {'est': LogisticRegression(C=0.1, l1_ratio=0.5...              0.807
# 8   {'est': LogisticRegression(C=0.1, l1_ratio=0.5...              0.814
# 7   {'est': LogisticRegression(C=0.1, l1_ratio=0.5...              0.814
# 6   {'est': LogisticRegression(C=0.1, l1_ratio=0.5...              0.814
# 10  {'est': LogisticRegression(C=0.1, l1_ratio=0.5...              0.815
# 9   {'est': LogisticRegression(C=0.1, l1_ratio=0.5...              0.815
# 11  {'est': LogisticRegression(C=0.1, l1_ratio=0.5...              0.815
# 15  {'est': TreeGAMClassifier(n_boosting_rounds=10...              0.809
# 12  {'est': RuleFitClassifier(max_rules=30), 'est_...              0.808
# 14  {'est': TreeGAMClassifier(n_boosting_rounds=10...              0.787
# 13  {'est': RuleFitClassifier(max_rules=30), 'est_...              0.823
# 19  {'est': FIGSClassifier(max_rules=12), 'est__ma...              0.792
# 1   {'est': DecisionTreeClassifier(), 'est__max_le...              0.766
# 18  {'est': FIGSClassifier(max_rules=12), 'est__ma...              0.776
# 2   {'est': DecisionTreeClassifier(), 'est__max_le...              0.793
# 16  {'est': HSTreeClassifier(est=DecisionTreeClass...              0.788
# 17  {'est': HSTreeClassifier(est=DecisionTreeClass...              0.788
# 0   {'est': DecisionTreeClassifier(), 'est__max_le...              0.670
#
#     split1_test_score  split2_test_score
# 4               0.853              0.815
# 3               0.852              0.806
# 5               0.850              0.813
# 8               0.853              0.799
# 7               0.853              0.797
# 6               0.853              0.795
# 10              0.853              0.792
# 9               0.853              0.792
# 11              0.853              0.792
# 15              0.802              0.820
# 12              0.808              0.814
# 14              0.812              0.810
# 13              0.791              0.774
# 19              0.792              0.728
# 1               0.791              0.733
# 18              0.799              0.713
# 2               0.751              0.723
# 16              0.732              0.693
# 17              0.726              0.693
# 0               0.718              0.704

# %%
est = m.est_.best_estimator_.named_steps['est']
print(est)
# Out:
# LogisticRegression(C=0.1, l1_ratio=0.5, penalty='elasticnet', solver='saga')

# %%
pd.DataFrame({'feature_names': feature_names, 'coef': est.coef_.flatten()}).round(3)
# Out:
#                  feature_names   coef
# 0                     Pregnant  0.295
# 1               plasma_glucose  0.914
# 2     Diastolic_blood_pressure -0.135
# 3  Triceps_skin_fold_thickness  0.000
# 4       X_2-Hour_serum_insulin -0.012
# 5              Body_mass_index  0.561
# 6   Diabetes_pedigree_function  0.299
# 7                          Age  0.135
